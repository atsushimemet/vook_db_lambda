# %%
import os

# カレントディレクトリを変更
os.chdir("..")  # notebookディレクトリの1つ上に移動
import pandas as pd

from vook_db_v7.rds_handler import get_knowledges
from vook_db_v7.utils import (
    DataFrame_maker_rakuten,
    DataFrame_maker_yahoo,
    create_api_input,
    repeat_dataframe_maker,
)
# Out:
# Now: Local env

# %%
df_api_input = create_api_input()
# Out:
# Local bind port: 60370
# エラーワード　BIG Eが存在しました:
# BIG EをBIGEに変換します
# エラーワード　BIG Eが存在しました:
# BIG EをBIGEに変換します
# エラーワード　BIG Eが存在しました:
# BIG EをBIGEに変換します
# エラーワード　BIG Eが存在しました:
# BIG EをBIGEに変換します

# %%
# df_bulkの作成
l_df_bulk = []
for platform_id, func in zip([1, 2], [DataFrame_maker_rakuten, DataFrame_maker_yahoo]):
    df_bulk = repeat_dataframe_maker(df_api_input, platform_id, func)
    l_df_bulk.append(df_bulk)
df_bulk = pd.concat(l_df_bulk, axis=0, ignore_index=True)
# Out:
# 000, 検索キーワード:[Levi's 501 66前期 中古] knowledge_id: 5
# Finished!!
# Finished!!
# Finished!!
# Finished!!
# Finished!!
# 返ってきた商品数の数が0なので、ループ終了
# price type before: object
# price type after: int64
# 001, 検索キーワード:[U.S.ARMY M-65 FIELD JACKET 1st 中古] knowledge_id: 8
# Finished!!
# 返ってきた商品数の数が0なので、ループ終了
# price type before: object
# price type after: int64
# 002, 検索キーワード:[Levi's 501 BIGE 中古] knowledge_id: 10
# Finished!!
# Finished!!
# Finished!!
# Finished!!
# Finished!!
# Finished!!
# Finished!!
# Finished!!
# Finished!!
# 返ってきた商品数の数が0なので、ループ終了
# price type before: object
# price type after: int64
# repeat_dataframe_makerの実行時間: 23秒
# 000, 検索キーワード:[Levi's 501 66前期 中古] knowledge_id: 5
# Get Data
# Get Data
# Get Data
# Get Data
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# Bad request
# 001, 検索キーワード:[U.S.ARMY M-65 FIELD JACKET 1st 中古] knowledge_id: 8
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# Bad request
# 002, 検索キーワード:[Levi's 501 BIGE 中古] knowledge_id: 10
# Get Data
# Get Data
# Get Data
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# If the number of returned items is 0, the loop ends.
# Get Data
# Bad request
# repeat_dataframe_makerの実行時間: 13秒

# %%
# 商品名に基づくフィルタリング処理を行う関数
def filter_by_name(df, filter_value):
    # 商品名からスペースを取り除いて、フィルターに一致するレコードだけを残す
    return df[df["name"].str.replace(" ", "").str.contains(filter_value)].copy()


# 全てのknowledge_idに対してフィルタリング処理を実行する関数
def filter_bulk_by_knowledge(df_bulk):
    # get_knowledges 関数を使用して知識情報を取得
    df_knowledges = get_knowledges()[
        ["knowledge_id", "knowledge_name", "line_name"]
    ].copy()

    # 結果を格納するリストを初期化
    filtered_dfs = []

    # df_bulk に含まれるすべての knowledge_id でループ
    for knowledge_id in df_bulk["knowledge_id"].unique():
        # 指定された knowledge_id に対応する line_name と knowledge_name を取得
        knowledge_info = df_knowledges[df_knowledges["knowledge_id"] == knowledge_id]
        if knowledge_info.empty:
            continue  # 該当する知識情報がない場合はスキップ

        line_name = knowledge_info["line_name"].values[0]
        knowledge_name = knowledge_info["knowledge_name"].values[0]

        # 対象のデータを一時的にコピー
        df_bulk_tmp = df_bulk[df_bulk["knowledge_id"] == knowledge_id].copy()

        print(
            f"Processing knowledge_id: {knowledge_id}, initial shape: {df_bulk_tmp.shape}"
        )

        # line_name でフィルタリング
        df_bulk_tmp = filter_by_name(df_bulk_tmp, line_name)
        print(f"After line filter, shape: {df_bulk_tmp.shape}")

        # knowledge_name でフィルタリング
        df_bulk_tmp = filter_by_name(df_bulk_tmp, knowledge_name)
        print(f"After knowledge filter, shape: {df_bulk_tmp.shape}")

        # フィルタリング結果をリストに追加
        filtered_dfs.append(df_bulk_tmp)

    # 結果を1つのデータフレームに統合
    if filtered_dfs:
        return pd.concat(filtered_dfs, ignore_index=True)
        print("Final combined shape:", df_filtered_bulk.shape)
    else:
        return pd.DataFrame()  # データがない場合の空データフレーム
        print("No matching records found")

# %%
# フィルタリング処理の呼び出し
df_filtered_bulk = filter_bulk_by_knowledge(df_bulk)

# 結果を出力
print("Filtered DataFrame:")
df_filtered_bulk
# Out:
# Local bind port: 60535
# Processing knowledge_id: 5, initial shape: (629, 9)
# After line filter, shape: (601, 9)
# After knowledge filter, shape: (490, 9)
# Processing knowledge_id: 8, initial shape: (3, 9)
# After line filter, shape: (0, 9)
# After knowledge filter, shape: (0, 9)
# Processing knowledge_id: 10, initial shape: (574, 9)
# After line filter, shape: (560, 9)
# After knowledge filter, shape: (0, 9)
# Filtered DataFrame:
#       id                                               name  \
# 0    NaN  【中古】LEVI’S　デニムパンツ 501 66前期 スモールe ボタン裏6 インディゴ サ...
# 1    NaN  【中古】Levi’s◆VT/70s/66前期/501/ストレートパンツ/44/デニム/IDG...
# 2    NaN  Levi's(リーバイス) サイズ:W29/30 70S VINTAGE 501 66前期 ...
# 3    NaN  【中古】Levi’s◆VT/70s/66前期/501//ストレートパンツ/48/デニム/ID...
# 4    NaN  【中古】Levi’s◆ボタン裏6/501/66前期/赤耳/ボトム/デニム/インディゴ【メンズ...
# ..   ...                                                ...
# 485  485  【中古】Levi's Vintage リーバイス ヴィンテージ/ビンテージ 501 66前期...
# 486  488  中古 LEVIS リーバイス 501 66前期 オリジナル 実寸W33程度/リーバイス/ヴィ...
# 487  489  ビンテージ70's★Levi's 501 66前期デニムカットオフショーツW93cm★200...
# 488  492  中古  LEVI'Sリーバイス501 66前期ヴィンテージデニムW30/オリジナル/ポケット...
# 489  493  ビンテージ70's●Levi’s 501 66前期カットオフショーツ実寸W71cm●odst...
#
#                                                    url   price knowledge_id  \
# 0    https://hb.afl.rakuten.co.jp/hgc/g00q49je.brn1...  550550            5
# 1    https://hb.afl.rakuten.co.jp/hgc/g00r3cee.brn1...  308660            5
# 2    https://hb.afl.rakuten.co.jp/hgc/g00s6rie.brn1...  261800            5
# 3    https://hb.afl.rakuten.co.jp/hgc/g00r3cee.brn1...  220660            5
# 4    https://hb.afl.rakuten.co.jp/hgc/g00r3cee.brn1...  198660            5
# ..                                                 ...     ...          ...
# 485  https://store.shopping.yahoo.co.jp/brand-life/...    4378            5
# 486  https://store.shopping.yahoo.co.jp/brand-life/...    4048            5
# 487  https://store.shopping.yahoo.co.jp/cozyvintage...    3850            5
# 488  https://store.shopping.yahoo.co.jp/brand-life/...    3278            5
# 489  https://store.shopping.yahoo.co.jp/cozyvintage...    3080            5
#
#     platform_id size_id                  created_at  \
# 0             1     999  2024-09-16 09:54:30.613444
# 1             1     999  2024-09-16 09:54:30.613444
# 2             1     999  2024-09-16 09:54:30.613444
# 3             1     999  2024-09-16 09:54:30.613444
# 4             1     999  2024-09-16 09:54:30.613444
# ..          ...     ...                         ...
# 485           2     999  2024-09-16 09:54:49.665829
# 486           2     999  2024-09-16 09:54:49.665901
# 487           2     999  2024-09-16 09:54:49.665925
# 488           2     999  2024-09-16 09:54:49.665997
# 489           2     999  2024-09-16 09:54:49.666022
#
#                      updated_at
# 0    2024-09-16 09:54:30.613444
# 1    2024-09-16 09:54:30.613444
# 2    2024-09-16 09:54:30.613444
# 3    2024-09-16 09:54:30.613444
# 4    2024-09-16 09:54:30.613444
# ..                          ...
# 485  2024-09-16 09:54:49.665837
# 486  2024-09-16 09:54:49.665909
# 487  2024-09-16 09:54:49.665933
# 488  2024-09-16 09:54:49.666005
# 489  2024-09-16 09:54:49.666029
#
# [490 rows x 9 columns]

# %% [markdown]
# # テスト

# %%
# df_bulkに含まれているノイズを含んだレコードがdf_bulk_tmpに含まれていないこと
## ex. 【メキシコ製】リーバイス\u3000デニム\u3000501モデル\u300030インチ
# df_bulkに含まれているノイズを含んでいないレコードがdf_bulk_tmpに含まれていること
## ex. Levi'sリーバイス 501 デニムパンツ w33 L30★SDP2865 ジーンズ ストレート ヒゲ ストーンウォッシュ 66 前期 シングル

# %%
def test_1():
    assert len(
        df_bulk[
            [
                "【メキシコ製】リーバイス\u3000デニム\u3000501モデル\u300030インチ"
                in name
                for name in df_bulk["name"]
            ]
        ]
    )
    assert not len(
        df_filtered_bulk[
            [
                "【メキシコ製】リーバイス\u3000デニム\u3000501モデル\u300030インチ"
                in name
                for name in df_filtered_bulk["name"]
            ]
        ]
    )


test_1()

# %%
def test_2():
    assert len(
        df_bulk[
            [
                "Levi'sリーバイス 501 デニムパンツ w33 L30★SDP2865 ジーンズ ストレート ヒゲ ストーンウォッシュ 66 前期 シングル"
                in name
                for name in df_bulk["name"]
            ]
        ]
    )
    assert len(
        df_filtered_bulk[
            [
                "Levi'sリーバイス 501 デニムパンツ w33 L30★SDP2865 ジーンズ ストレート ヒゲ ストーンウォッシュ 66 前期 シングル"
                in name
                for name in df_filtered_bulk["name"]
            ]
        ]
    )


test_2()

# %% [markdown]
# # エラー調査

# %%
# issue 7
# 変更前後の501 BIG Eの商品レコード数をかぞえる
bfr_cnt = df_bulk[df_bulk["knowledge_id"] == 10].shape[0]
aft_cnt = df_filtered_bulk[df_filtered_bulk["knowledge_id"] == 10].shape[0]
print("bfr_cnt:", bfr_cnt)
print("aft_cnt:", aft_cnt)
# Out:
# bfr_cnt: 574
# aft_cnt: 0

# %%
# filter_by_nameの変更前のBIG Eフィルター結果をかぞえる
filter_value = "BIG E"
filter_value = "BIGE"
df_bulk_tmp = df_bulk[df_bulk["knowledge_id"] == 10]
df_bulk_tmp[df_bulk_tmp["name"].str.replace(" ", "").str.contains(filter_value)].copy()
# Out:
#        id                                               name  \
# 139   NaN  【中古】Levi’s◆ボトム/60s/501xx/BIG E/初期/ボタン裏刻印E/IDG/...
# 140   NaN  【中古】Levi’s◆ストレートパンツ/--/コットン/IDG/501/BIGE//【メンズ...
# 141   NaN  古着 グッドコンディション 60'S リーバイス Levi's リーバイス501 Aタイプ ...
# 142   NaN  【中古】Levi’s◆60s/501/BIE/Sタイプ/実寸W39L30/ウエストチェーン平...
# 143   NaN  Levi's(リーバイス) 40s VINTAGE S501XX 大戦モデル 片面タブ BI...
# ...   ...                                                ...
# 1196  296     Levis(リーバイス) 501 BIGE 赤耳 メンズ  28/34 中古 古着 0708
# 1197  297  リーバイス Levis 90S USA製 501 BIGE 110周年モデル バレンシア ボ...
# 1200  300  Levis(リーバイス) PREMIUM 501 復刻BIGE ボタンフライデニムパンツ メ...
# 1203  303  未使用 Levi’s リーバイス 04511-2301 W27 米国製 MADE IN US...
# 1205  305  リーバイス Levi's 501 ボタンフライ 日本製  BIGE  デニムパンツ メンズ ...
#
#                                                     url   price knowledge_id  \
# 139   https://hb.afl.rakuten.co.jp/hgc/g00r3cee.brn1...  451660           10
# 140   https://hb.afl.rakuten.co.jp/hgc/g00r3cee.brn1...  440660           10
# 141   https://hb.afl.rakuten.co.jp/hgc/g00qhzfe.brn1...  439890           10
# 142   https://hb.afl.rakuten.co.jp/hgc/g00r3cee.brn1...  429660           10
# 143   https://hb.afl.rakuten.co.jp/hgc/g00s6rie.brn1...  396000           10
# ...                                                 ...     ...          ...
# 1196  https://store.shopping.yahoo.co.jp/bazzstore/1...    5489           10
# 1197  https://store.shopping.yahoo.co.jp/bazzstore/8...    5270           10
# 1200  https://store.shopping.yahoo.co.jp/bazzstore/1...    4169           10
# 1203  https://store.shopping.yahoo.co.jp/reuseshopla...    3300           10
# 1205  https://store.shopping.yahoo.co.jp/bazzstore/8...    1479           10
#
#      platform_id size_id                  created_at  \
# 139            1     999  2024-09-16 09:54:45.872401
# 140            1     999  2024-09-16 09:54:45.872401
# 141            1     999  2024-09-16 09:54:45.872401
# 142            1     999  2024-09-16 09:54:45.872401
# 143            1     999  2024-09-16 09:54:45.872401
# ...          ...     ...                         ...
# 1196           2     999  2024-09-16 09:54:56.328056
# 1197           2     999  2024-09-16 09:54:56.328068
# 1200           2     999  2024-09-16 09:54:56.328105
# 1203           2     999  2024-09-16 09:54:57.522577
# 1205           2     999  2024-09-16 09:54:57.522702
#
#                       updated_at
# 139   2024-09-16 09:54:45.872401
# 140   2024-09-16 09:54:45.872401
# 141   2024-09-16 09:54:45.872401
# 142   2024-09-16 09:54:45.872401
# 143   2024-09-16 09:54:45.872401
# ...                          ...
# 1196  2024-09-16 09:54:56.328059
# 1197  2024-09-16 09:54:56.328072
# 1200  2024-09-16 09:54:56.328109
# 1203  2024-09-16 09:54:57.522595
# 1205  2024-09-16 09:54:57.522720
#
# [470 rows x 9 columns]

# %%
# 全てのknowledge_idに対してフィルタリング処理を実行する関数
def filter_bulk_by_knowledge(df_bulk):
    # get_knowledges 関数を使用して知識情報を取得
    df_knowledges = get_knowledges()[
        ["knowledge_id", "knowledge_name", "line_name"]
    ].copy()

    # 結果を格納するリストを初期化
    filtered_dfs = []

    # df_bulk に含まれるすべての knowledge_id でループ
    for knowledge_id in df_bulk["knowledge_id"].unique():
        # 指定された knowledge_id に対応する line_name と knowledge_name を取得
        knowledge_info = df_knowledges[df_knowledges["knowledge_id"] == knowledge_id]
        if knowledge_info.empty:
            continue  # 該当する知識情報がない場合はスキップ

        line_name = knowledge_info["line_name"].values[0]
        knowledge_name = knowledge_info["knowledge_name"].values[0]

        # 対象のデータを一時的にコピー
        df_bulk_tmp = df_bulk[df_bulk["knowledge_id"] == knowledge_id].copy()

        print(
            f"Processing knowledge_id: {knowledge_id}, initial shape: {df_bulk_tmp.shape}"
        )

        # line_name でフィルタリング
        df_bulk_tmp = filter_by_name(df_bulk_tmp, line_name)
        print(f"After line filter, shape: {df_bulk_tmp.shape}")

        # knowledge_name でフィルタリング
        df_bulk_tmp = filter_by_name(df_bulk_tmp, knowledge_name)
        print(f"After knowledge filter, shape: {df_bulk_tmp.shape}")

        # フィルタリング結果をリストに追加
        filtered_dfs.append(df_bulk_tmp)

    # 結果を1つのデータフレームに統合
    if filtered_dfs:
        return pd.concat(filtered_dfs, ignore_index=True)
        print("Final combined shape:", df_filtered_bulk.shape)
    else:
        return pd.DataFrame()  # データがない場合の空データフレーム
        print("No matching records found")


# 全てのknowledge_idに対してフィルタリング処理を実行する関数
def filter_bulk_by_knowledge2(df_bulk):
    # get_knowledges 関数を使用して知識情報を取得
    df_knowledges = get_knowledges()[
        ["knowledge_id", "knowledge_name", "line_name"]
    ].copy()

    # 結果を格納するリストを初期化
    filtered_dfs = []

    # df_bulk に含まれるすべての knowledge_id でループ
    for knowledge_id in df_bulk["knowledge_id"].unique():
        # 指定された knowledge_id に対応する line_name と knowledge_name を取得
        knowledge_info = df_knowledges[df_knowledges["knowledge_id"] == knowledge_id]
        if knowledge_info.empty:
            continue  # 該当する知識情報がない場合はスキップ

        line_name = knowledge_info["line_name"].values[0].replace(" ", "")
        knowledge_name = knowledge_info["knowledge_name"].values[0].replace(" ", "")

        # 対象のデータを一時的にコピー
        df_bulk_tmp = df_bulk[df_bulk["knowledge_id"] == knowledge_id].copy()

        print(
            f"Processing knowledge_id: {knowledge_id}, initial shape: {df_bulk_tmp.shape}"
        )

        # line_name でフィルタリング
        df_bulk_tmp = filter_by_name(df_bulk_tmp, line_name)
        print(f"After line filter, shape: {df_bulk_tmp.shape}")

        # knowledge_name でフィルタリング
        df_bulk_tmp = filter_by_name(df_bulk_tmp, knowledge_name)
        print(f"After knowledge filter, shape: {df_bulk_tmp.shape}")

        # フィルタリング結果をリストに追加
        filtered_dfs.append(df_bulk_tmp)

    # 結果を1つのデータフレームに統合
    if filtered_dfs:
        return pd.concat(filtered_dfs, ignore_index=True)
        print("Final combined shape:", df_filtered_bulk.shape)
    else:
        return pd.DataFrame()  # データがない場合の空データフレーム
        print("No matching records found")

# %%
filter_bulk_by_knowledge(df_bulk)
# Out:
# Local bind port: 60539
# Processing knowledge_id: 5, initial shape: (629, 9)
# After line filter, shape: (601, 9)
# After knowledge filter, shape: (490, 9)
# Processing knowledge_id: 8, initial shape: (3, 9)
# After line filter, shape: (0, 9)
# After knowledge filter, shape: (0, 9)
